# %% [markdown]
# # <center><u><font color='red'> Prédiction consommation d'énergie2</font></u></center>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt

from sklearn.linear_model import Ridge,Lasso,ElasticNet,LinearRegression
from sklearn.dummy import DummyRegressor
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor
from sklearn.model_selection import train_test_split
from functions import utils
import math
from sklearn.svm import SVR
from xgboost import XGBRegressor 
from functions.functions import *
from sklearn.neural_network import MLPRegressor
import warnings
warnings.filterwarnings('ignore')
from IPython.display import display
pd.options.display.float_format = '{:,.4f}'.format

# %%
target_col='SiteEnergyUse(kBtu)'
stratify_col='PrimaryPropertyType'

# %%
df=pd.read_csv('data/cleaned_and_normalized_pca.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 993 entries, 0 to 992
# Data columns (total 39 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   pca_0                993 non-null    float64
#  1   pca_1                993 non-null    float64
#  2   pca_2                993 non-null    float64
#  3   pca_3                993 non-null    float64
#  4   pca_4                993 non-null    float64
#  5   pca_5                993 non-null    float64
#  6   pca_6                993 non-null    float64
#  7   pca_7                993 non-null    float64
#  8   pca_8                993 non-null    float64
#  9   pca_9                993 non-null    float64
#  10  pca_10               993 non-null    float64
#  11  pca_11               993 non-null    float64
#  12  pca_12               993 non-null    float64
#  13  pca_13               993 non-null    float64
#  14  pca_14               993 non-null    float64
#  15  pca_15               993 non-null    float64
#  16  pca_16               993 non-null    float64
#  17  pca_17               993 non-null    float64
#  18  pca_18               993 non-null    float64
#  19  pca_19               993 non-null    float64
#  20  pca_20               993 non-null    float64
#  21  pca_21               993 non-null    float64
#  22  pca_22               993 non-null    float64
#  23  pca_23               993 non-null    float64
#  24  pca_24               993 non-null    float64
#  25  pca_25               993 non-null    float64
#  26  pca_26               993 non-null    float64
#  27  pca_27               993 non-null    float64
#  28  pca_28               993 non-null    float64
#  29  pca_29               993 non-null    float64
#  30  pca_30               993 non-null    float64
#  31  pca_31               993 non-null    float64
#  32  pca_32               993 non-null    float64
#  33  pca_33               993 non-null    float64
#  34  pca_34               993 non-null    float64
#  35  pca_35               993 non-null    float64
#  36  BuildingType         993 non-null    object
#  37  TotalGHGEmissions    993 non-null    float64
#  38  SiteEnergyUse(kBtu)  993 non-null    float64
# dtypes: float64(38), object(1)
# memory usage: 302.7+ KB

# %%
df.head()
# Out:
#    pca_0   pca_1   pca_2   pca_3   pca_4   pca_5   pca_6   pca_7   pca_8  \
# 0 4.0341 -2.2225  3.4706  0.3884 -1.1989  1.4803  5.5414 -0.0777  0.1388
# 1 0.5075 -1.7344  1.9091 -0.3307 -0.6477  0.0908  0.5726 -0.0114 -0.7945
# 2 1.7649 -0.4836 -1.7048  0.5458  0.5272 -0.6925  2.4083 -0.6399 -1.0747
# 3 0.9358 -0.2651  2.4654 -0.2529 -0.0739  0.1274 -0.6701  0.5069 -0.5936
# 4 0.7743  1.2464  2.7930 -0.0597  1.8443  1.3994  1.7014 -0.9865  0.5436
#
#     pca_9  ...  pca_29  pca_30  pca_31  pca_32  pca_33  pca_34  pca_35  \
# 0 -2.7239  ... -1.3215  1.9854 -1.8777  0.7934  0.6241  1.5591 -0.6630
# 1 -0.8958  ... -2.5355 -1.9163 -1.1657 -0.5478  0.3158 -0.5670  0.3015
# 2 -0.7783  ... -1.4236 -7.0171 -3.3748 -7.3312 -4.5387  0.0880 -2.7381
# 3  0.0733  ...  0.0066 -0.0050  0.0062 -0.0116 -0.0080  0.0374 -0.0064
# 4 -0.3433  ... -0.4315  0.3191  0.0082  0.1656 -0.2187  0.4844 -0.0132
#
#      BuildingType  TotalGHGEmissions  SiteEnergyUse(kBtu)
# 0  NonResidential           221.5100       6,298,131.5000
# 1  NonResidential           273.0200       7,606,084.5000
# 2  NonResidential             9.1300       1,310,236.6250
# 3  NonResidential           157.7700       4,145,920.5000
# 4  NonResidential           215.0000       6,668,568.5000
#
# [5 rows x 39 columns]

# %%
cols=['best_params','R2','rmse','model','time_elapsed']
df_result=pd.DataFrame(columns=cols)
df_result_with_energy_star_score=pd.DataFrame(columns=cols)

# %%
test_size=0.25
random_state=42
cv=5
scoring='r2'
feature_cols=[col for col in df.columns.tolist() if col not in ['TotalGHGEmissions','SiteEnergyUse(kBtu)','ENERGYSTARScore',stratify_col]]

 
feature_cols_with_energy_star_score=[col for col in df.columns.tolist() if col not in ['TotalGHGEmissions','SiteEnergyUse(kBtu)','ENERGYSTARScore',stratify_col]]

# %%
stratify=df[[stratify_col]]
X_train,X_test,y_train,y_test=train_test_split(df[feature_cols],df[target_col],test_size=test_size,random_state=random_state)
X_train_with_energy_star_score=X_train[feature_cols_with_energy_star_score]
X_test_with_energy_star_score=X_test[feature_cols_with_energy_star_score]
train_y=y_train.values
test_y=y_test.values

# %% [markdown]
# ## Partie 1 modèles linéaires

# %% [markdown]
# ### 1 <u>Modèle linéaire simple</u>

# %% [markdown]
# #### 1-1 <u>Régression linéaire sans ENERGYSTARScore </u>

# %%
train_x=X_train.values
test_x=X_test.values
 

result=utils.model_func(df,LinearRegression(),target_col,feature_cols,test_size,random_state,train_x,test_x,train_y,test_y)

df_result=df_result.append(result,ignore_index = True)
df_result
# Out:
#   best_params     R2           rmse             model  time_elapsed
# 0        None 0.3678 1,566,504.5278  LinearRegression        0.0032

# %% [markdown]
# ### 2 <u>Régression de ridge</u>

# %% [markdown]
# #### 2-1 <u>Régression de ridge sans ENERGYSTARScore </u>

# %%
train_x=X_train_with_energy_star_score.values
test_x=X_test.values
 
param_grid = [{
    #'alpha':np.arange(0,1.01,0.01),
      'alpha':[0.92],
    'fit_intercept':[True,False],
  
  'solver':['auto', 'svd', 'cholesky', 'lsqr', 'sparse_cg', 'sag', 'saga', 'lbfgs']
}]



scoring = 'r2'
 
model = Ridge(random_state=random_state)
#ridge.best_params_,ridge.best_score_,rmse,model.__class__.__name__,elapsed
result=utils.grid_search_cv_func(df,target_col,feature_cols,param_grid,scoring,model,test_size,random_state,cv,train_x,test_x,train_y,test_y)

df_result=df_result.append(result,ignore_index = True)
print(result)
# Out:
# {'best_params': {'alpha': 0.92, 'fit_intercept': True, 'solver': 'saga'}, 'R2': 0.016845358804271626, 'rmse': 1560946.790675271, 'model': 'Ridge', 'time_elapsed': 0.4606081750098383}

# %% [markdown]
# ### 3 <u>Régression de Lasso</u>

# %% [markdown]
# #### 3-1 <u>Régression de Lasso sans ENERGYSTARScore </u>

# %%
train_x=X_train.values
test_x=X_test.values

 
param_grid = [{
    #'alpha':np.arange(3001,10001,1),
      'alpha':[5994],
    'fit_intercept':[True,False],
  
  
}]




 
model = Lasso( random_state=random_state)
result=utils.grid_search_cv_func(df,target_col,feature_cols,param_grid,scoring,model,test_size,random_state,cv,train_x,test_x,train_y,test_y)

df_result=df_result.append(result,ignore_index = True)
print(result)
df_result
# Out:
# {'best_params': {'alpha': 5994, 'fit_intercept': True}, 'R2': 0.08565930858749751, 'rmse': 1526027.5380663385, 'model': 'Lasso', 'time_elapsed': 0.04116496999631636}
#                                          best_params     R2           rmse  \
# 0                                               None 0.3678 1,566,504.5278
# 1  {'alpha': 0.92, 'fit_intercept': True, 'solver... 0.0168 1,560,946.7907
# 2             {'alpha': 5994, 'fit_intercept': True} 0.0857 1,526,027.5381
#
#               model  time_elapsed
# 0  LinearRegression        0.0032
# 1             Ridge        0.4606
# 2             Lasso        0.0412

# %% [markdown]
# ### 4 <u>Régression de ElasticNet</u>

# %% [markdown]
# #### 4-1 <u>Régression de ElasticNet sans ENERGYSTARScore </u>

# %%
train_x=X_train.values
test_x=X_test.values
 #param_grid = [{'alpha' : np.arange(0,0.2,0.001)}]
param_grid = [{"alpha": np.arange(0.01,1.01,0.01),  #coefficient qui multiplie le terme de pénalité
              "l1_ratio": np.arange(0, 0.01, 0.001)}]#L1 ratio si = 1 équivaut à un Lasso si 0 à un Ridge


 
model = ElasticNet( random_state=random_state,normalize=False)
result=utils.grid_search_cv_func(df,target_col,feature_cols,param_grid,scoring,model,test_size,random_state,cv,train_x,test_x,train_y,test_y)
df_result=df_result.append(result,ignore_index = True)
df_result
# Out:
#                                          best_params     R2           rmse  \
# 0                                               None 0.3678 1,566,504.5278
# 1  {'alpha': 0.92, 'fit_intercept': True, 'solver... 0.0168 1,560,946.7907
# 2             {'alpha': 5994, 'fit_intercept': True} 0.0857 1,526,027.5381
# 3   {'alpha': 0.5700000000000001, 'l1_ratio': 0.004} 0.3840 1,464,242.6419
#
#               model  time_elapsed
# 0  LinearRegression        0.0032
# 1             Ridge        0.4606
# 2             Lasso        0.0412
# 3        ElasticNet       17.8062

# %% [markdown]
# ## Partie 2 modèles non linéaires

# %% [markdown]
# ### 1 <u>Random Forest</u>

# %% [markdown]
# #### 1-1 <u>Random Forest sans ENERGYSTARScore </u>

# %%
train_x=X_train.values
test_x=X_test.values
 

'''
param_grid = {
'n_estimators':[5,20,50,100], # nombre d'arbres
'max_features':['auto', 'sqrt'], # nombre de variables tenu en compte pour la création de chaque arbre
'max_depth':np.arange(10,130,10), # nombre maximum de niveaux dans chaque arbre de décision 
'min_samples_split':[2, 6, 10], # nombre minimal d'observation avant séparation du noeud
'min_samples_leaf':[1, 3, 4], #nombre minimal d'observation pour créer une feuille
'bootstrap':[True, False] # méthode d'échantillonnage
}   
'''
 
## best params


param_grid={'bootstrap': [False],
  'max_depth': [40],
  'max_features': ['sqrt'],
  'min_samples_leaf': [1],
  'min_samples_split': [2],
  'n_estimators': [100]}

model = RandomForestRegressor(random_state=random_state)
result=utils.grid_search_cv_func(df,target_col,feature_cols,param_grid,scoring,model,test_size,random_state,cv,train_x,test_x,train_y,test_y)


df_result=df_result.append(result,ignore_index = True)
print(result)
df_result
# Out:
# {'best_params': {'bootstrap': False, 'max_depth': 40, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}, 'R2': 0.5331993202435591, 'rmse': 1443133.3475990146, 'model': 'RandomForestRegressor', 'time_elapsed': 2.678543603004073}
#                                          best_params     R2           rmse  \
# 0                                               None 0.3678 1,566,504.5278
# 1  {'alpha': 0.92, 'fit_intercept': True, 'solver... 0.0168 1,560,946.7907
# 2             {'alpha': 5994, 'fit_intercept': True} 0.0857 1,526,027.5381
# 3   {'alpha': 0.5700000000000001, 'l1_ratio': 0.004} 0.3840 1,464,242.6419
# 4  {'bootstrap': False, 'max_depth': 40, 'max_fea... 0.5332 1,443,133.3476
#
#                    model  time_elapsed
# 0       LinearRegression        0.0032
# 1                  Ridge        0.4606
# 2                  Lasso        0.0412
# 3             ElasticNet       17.8062
# 4  RandomForestRegressor        2.6785

# %%
#df_result['best_params']
#df_result.iloc[34][['best_params']]
result
# Out:
# {'best_params': {'bootstrap': False,
#   'max_depth': 40,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 1,
#   'min_samples_split': 2,
#   'n_estimators': 100},
#  'R2': 0.5331993202435591,
#  'rmse': 1443133.3475990146,
#  'model': 'RandomForestRegressor',
#  'time_elapsed': 2.678543603004073}

# %% [markdown]
#   ### 2 <u>XGBoost</u>

# %% [markdown]
# #### 2-1 <u>XGBoost sans ENERGYSTARScore </u>

# %%
 
train_x=X_train.values
test_x=X_test.values
 

'''
param_grid = {
    'learning_rate':np.arange(0.1,1,0.1),
    'n_estimators':  np.arange(50, 110, 10),  #nombre d'arbres de décision 50
              'max_depth': np.arange(20, 50, 5)} #nombre maximum de niveaux dans chaque arbre de décision 20
# define the model/ estimator
'''

param_grid={'learning_rate': [0.1], 'max_depth': [35], 'n_estimators': [50]}

model = XGBRegressor(random_state=random_state)
result=utils.grid_search_cv_func(df,target_col,feature_cols,param_grid,scoring,model,test_size,random_state,cv,train_x,test_x,train_y,test_y)


df_result=df_result.append(result,ignore_index = True)
df_result
# Out:
#                                          best_params     R2           rmse  \
# 0                                               None 0.3678 1,566,504.5278
# 1  {'alpha': 0.92, 'fit_intercept': True, 'solver... 0.0168 1,560,946.7907
# 2             {'alpha': 5994, 'fit_intercept': True} 0.0857 1,526,027.5381
# 3   {'alpha': 0.5700000000000001, 'l1_ratio': 0.004} 0.3840 1,464,242.6419
# 4  {'bootstrap': False, 'max_depth': 40, 'max_fea... 0.5332 1,443,133.3476
# 5  {'learning_rate': 0.1, 'max_depth': 35, 'n_est... 0.4409 1,599,814.7546
#
#                    model  time_elapsed
# 0       LinearRegression        0.0032
# 1                  Ridge        0.4606
# 2                  Lasso        0.0412
# 3             ElasticNet       17.8062
# 4  RandomForestRegressor        2.6785
# 5           XGBRegressor        2.9205

# %%
result
# Out:
# {'best_params': {'learning_rate': 0.1, 'max_depth': 35, 'n_estimators': 50},
#  'R2': 0.44092267886861547,
#  'rmse': 1599814.7545692725,
#  'model': 'XGBRegressor',
#  'time_elapsed': 2.920467092000763}

# %%
from sklearn.preprocessing import StandardScaler
Labels=df_result['model'].unique().tolist()
 
 
numeric_cols=['R2','rmse','time_elapsed']
fig, ax = plt.subplots(figsize=(40,15))
data_plot=df_result.copy()
data_plot['R2']=data_plot['R2']+2000000
data_plot['rmse']=data_plot['rmse']-20000
 
utils.bar_plot(ax,data_plot[['time_elapsed','rmse','R2']], total_width=1.5, single_width=0.9)
plt.xticks(range(len(Labels)), Labels, fontsize=20, rotation=45)

ttl = plt.title("modèles de prédictions consommation énergie sans energystartscore", fontsize=26)
ttl.set_position([.5, 1.03])
plt.show()

# %%
df_result.sort_values(by='R2',ascending=False)
# Out:
#                                          best_params     R2           rmse  \
# 4  {'bootstrap': False, 'max_depth': 40, 'max_fea... 0.5332 1,443,133.3476
# 5  {'learning_rate': 0.1, 'max_depth': 35, 'n_est... 0.4409 1,599,814.7546
# 3   {'alpha': 0.5700000000000001, 'l1_ratio': 0.004} 0.3840 1,464,242.6419
# 0                                               None 0.3678 1,566,504.5278
# 2             {'alpha': 5994, 'fit_intercept': True} 0.0857 1,526,027.5381
# 1  {'alpha': 0.92, 'fit_intercept': True, 'solver... 0.0168 1,560,946.7907
#
#                    model  time_elapsed
# 4  RandomForestRegressor        2.6785
# 5           XGBRegressor        2.9205
# 3             ElasticNet       17.8062
# 0       LinearRegression        0.0032
# 2                  Lasso        0.0412
# 1                  Ridge        0.4606
