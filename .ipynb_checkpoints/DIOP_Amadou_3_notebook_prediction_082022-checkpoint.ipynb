# %% [markdown]
# # <center><u><font color='red'> Prédiction consommation d'énergie2</font></u></center>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt

from sklearn.linear_model import Ridge,Lasso,ElasticNet,LinearRegression
from sklearn.dummy import DummyRegressor
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor
from sklearn.model_selection import train_test_split
from functions import utils
import math
from sklearn.svm import SVR
from xgboost import XGBRegressor 
from functions.functions import *
from sklearn.neural_network import MLPRegressor
import warnings
warnings.filterwarnings('ignore')
from IPython.display import display
pd.options.display.float_format = '{:,.4f}'.format

# %%
target_col='SiteEnergyUse(kBtu)'
stratify_col='PrimaryPropertyType'

# %%
df=pd.read_csv('data/cleaned_and_normalized_pca.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1541 entries, 0 to 1540
# Data columns (total 53 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   pca_0                1541 non-null   float64
#  1   pca_1                1541 non-null   float64
#  2   pca_2                1541 non-null   float64
#  3   pca_3                1541 non-null   float64
#  4   pca_4                1541 non-null   float64
#  5   pca_5                1541 non-null   float64
#  6   pca_6                1541 non-null   float64
#  7   pca_7                1541 non-null   float64
#  8   pca_8                1541 non-null   float64
#  9   pca_9                1541 non-null   float64
#  10  pca_10               1541 non-null   float64
#  11  pca_11               1541 non-null   float64
#  12  pca_12               1541 non-null   float64
#  13  pca_13               1541 non-null   float64
#  14  pca_14               1541 non-null   float64
#  15  pca_15               1541 non-null   float64
#  16  pca_16               1541 non-null   float64
#  17  pca_17               1541 non-null   float64
#  18  pca_18               1541 non-null   float64
#  19  pca_19               1541 non-null   float64
#  20  pca_20               1541 non-null   float64
#  21  pca_21               1541 non-null   float64
#  22  pca_22               1541 non-null   float64
#  23  pca_23               1541 non-null   float64
#  24  pca_24               1541 non-null   float64
#  25  pca_25               1541 non-null   float64
#  26  pca_26               1541 non-null   float64
#  27  pca_27               1541 non-null   float64
#  28  pca_28               1541 non-null   float64
#  29  pca_29               1541 non-null   float64
#  30  pca_30               1541 non-null   float64
#  31  pca_31               1541 non-null   float64
#  32  pca_32               1541 non-null   float64
#  33  pca_33               1541 non-null   float64
#  34  pca_34               1541 non-null   float64
#  35  pca_35               1541 non-null   float64
#  36  pca_36               1541 non-null   float64
#  37  pca_37               1541 non-null   float64
#  38  pca_38               1541 non-null   float64
#  39  pca_39               1541 non-null   float64
#  40  pca_40               1541 non-null   float64
#  41  pca_41               1541 non-null   float64
#  42  pca_42               1541 non-null   float64
#  43  pca_43               1541 non-null   float64
#  44  pca_44               1541 non-null   float64
#  45  pca_45               1541 non-null   float64
#  46  pca_46               1541 non-null   float64
#  47  pca_47               1541 non-null   float64
#  48  pca_48               1541 non-null   float64
#  49  pca_49               1541 non-null   float64
#  50  PrimaryPropertyType  1541 non-null   object
#  51  TotalGHGEmissions    1541 non-null   float64
#  52  SiteEnergyUse(kBtu)  1541 non-null   float64
# dtypes: float64(52), object(1)
# memory usage: 638.2+ KB

# %%
df.head()
# Out:
#     pca_0   pca_1   pca_2   pca_3   pca_4  pca_5   pca_6  pca_7  pca_8  \
# 0  0.2698 -0.4683 -1.0268 -1.5179 -0.8687 0.8241 -0.4179 0.4523 0.3812
# 1  0.1120 -0.0092 -2.0328  0.0130 -1.0090 0.4773 -0.5255 0.7194 0.5387
# 2  6.1147 -3.1739 -5.8743  0.1846 -5.7726 5.4456 -2.5186 3.7719 2.7266
# 3 -0.0829 -0.0791 -1.2278 -1.4600 -0.8222 0.6423 -0.2737 0.3354 0.2820
# 4  0.8852 -0.6083 -2.9170 -0.1295 -0.9615 0.6640 -0.4658 0.8654 0.6122
#
#     pca_9  ...  pca_43  pca_44  pca_45  pca_46  pca_47  pca_48  pca_49  \
# 0 -0.0616  ... -0.0060 -0.0090 -0.0175  0.0194  0.0048 -0.0191 -0.0075
# 1 -0.0590  ... -0.0062 -0.0154 -0.0110  0.0189  0.0041 -0.0162 -0.0040
# 2 -0.2225  ... -0.0650 -0.1046 -0.1515  0.1824  0.0196 -0.1631 -0.0461
# 3 -0.0396  ... -0.0034 -0.0049 -0.0112  0.0123  0.0042 -0.0124 -0.0056
# 4 -0.0564  ... -0.0078 -0.0197 -0.0205  0.0268  0.0067 -0.0246 -0.0071
#
#    PrimaryPropertyType  TotalGHGEmissions  SiteEnergyUse(kBtu)
# 0                Hotel           249.9800       7,226,362.5000
# 1                Hotel           295.8600       8,387,933.0000
# 2                Hotel         2,089.2800      72,587,024.0000
# 3                Hotel           286.4300       6,794,584.0000
# 4                Hotel           505.0100      14,172,606.0000
#
# [5 rows x 53 columns]

# %%
cols=['best_params','R2','rmse','model','time_elapsed']
df_result=pd.DataFrame(columns=cols)
df_result_with_energy_star_score=pd.DataFrame(columns=cols)

# %%
test_size=0.25
random_state=42
cv=5
scoring='r2'
feature_cols=[col for col in df.columns.tolist() if col not in ['TotalGHGEmissions','SiteEnergyUse(kBtu)','ENERGYSTARScore',stratify_col]]

 
feature_cols_with_energy_star_score=[col for col in df.columns.tolist() if col not in ['TotalGHGEmissions','SiteEnergyUse(kBtu)','ENERGYSTARScore',stratify_col]]

# %%
stratify=df[[stratify_col]]
X_train,X_test,y_train,y_test=train_test_split(df[feature_cols],df[target_col],test_size=test_size,random_state=random_state)
X_train_with_energy_star_score=X_train[feature_cols_with_energy_star_score]
X_test_with_energy_star_score=X_test[feature_cols_with_energy_star_score]
train_y=y_train.values
test_y=y_test.values

# %% [markdown]
# ## Partie 1 modèles linéaires

# %% [markdown]
# ### 1 <u>Modèle linéaire simple</u>

# %% [markdown]
# #### 1-1 <u>Régression linéaire sans ENERGYSTARScore </u>

# %%
train_x=X_train.values
test_x=X_test.values
 

result=utils.model_func(df,LinearRegression(),target_col,feature_cols,test_size,random_state,train_x,test_x,train_y,test_y)

df_result=df_result.append(result,ignore_index = True)
df_result
# Out:
#   best_params     R2            rmse             model  time_elapsed
# 0        None 0.3720 23,078,351.5894  LinearRegression        0.0033

# %% [markdown]
# ### 2 <u>Régression de ridge</u>

# %% [markdown]
# #### 2-1 <u>Régression de ridge sans ENERGYSTARScore </u>

# %%
train_x=X_train_with_energy_star_score.values
test_x=X_test.values
 
param_grid = [{
    #'alpha':np.arange(16,21,0.1),
      'alpha':[17.700000000000024],
    'fit_intercept':[True,False],
  
  'solver':['auto', 'svd', 'cholesky', 'lsqr', 'sparse_cg', 'sag', 'saga', 'lbfgs']
}]



scoring = 'r2'
 
model = Ridge(random_state=random_state)
#ridge.best_params_,ridge.best_score_,rmse,model.__class__.__name__,elapsed
result=utils.grid_search_cv_func(df,target_col,feature_cols,param_grid,scoring,model,test_size,random_state,cv,train_x,test_x,train_y,test_y)

df_result=df_result.append(result,ignore_index = True)
print(result)
# Out:
# {'best_params': {'alpha': 17.700000000000024, 'fit_intercept': True, 'solver': 'saga'}, 'R2': 0.8012143540772467, 'rmse': 23866764.35648314, 'model': 'Ridge', 'time_elapsed': 1.533280603995081}

# %% [markdown]
# ### 3 <u>Régression de Lasso</u>

# %% [markdown]
# #### 3-1 <u>Régression de Lasso sans ENERGYSTARScore </u>

# %%
train_x=X_train.values
test_x=X_test.values

 
param_grid = [{
    #'alpha':np.arange(100000,200000,100),
     'alpha':[101300],
    'fit_intercept':[True,False],
  
  
}]




 
model = Lasso( random_state=random_state)
result=utils.grid_search_cv_func(df,target_col,feature_cols,param_grid,scoring,model,test_size,random_state,cv,train_x,test_x,train_y,test_y)

df_result=df_result.append(result,ignore_index = True)
print(result)
df_result
# Out:
# {'best_params': {'alpha': 101300, 'fit_intercept': True}, 'R2': 0.784645078913503, 'rmse': 23906217.403273195, 'model': 'Lasso', 'time_elapsed': 0.06619407801190391}
#                                          best_params     R2            rmse  \
# 0                                               None 0.3720 23,078,351.5894
# 1  {'alpha': 17.700000000000024, 'fit_intercept':... 0.8012 23,866,764.3565
# 2           {'alpha': 101300, 'fit_intercept': True} 0.7846 23,906,217.4033
#
#               model  time_elapsed
# 0  LinearRegression        0.0033
# 1             Ridge        1.5333
# 2             Lasso        0.0662

# %% [markdown]
# ### 4 <u>Régression de ElasticNet</u>

# %% [markdown]
# #### 4-1 <u>Régression de ElasticNet sans ENERGYSTARScore </u>

# %%
train_x=X_train.values
test_x=X_test.values
 #param_grid = [{'alpha' : np.arange(0,0.2,0.001)}]
param_grid = [{"alpha": np.arange(0.01,1.01,0.01),  #coefficient qui multiplie le terme de pénalité
              "l1_ratio": np.arange(0, 0.01, 0.001)}]#L1 ratio si = 1 équivaut à un Lasso si 0 à un Ridge


 
model = ElasticNet( random_state=random_state,normalize=False)
result=utils.grid_search_cv_func(df,target_col,feature_cols,param_grid,scoring,model,test_size,random_state,cv,train_x,test_x,train_y,test_y)
df_result=df_result.append(result,ignore_index = True)
df_result
# Out:
#                                          best_params     R2            rmse  \
# 0                                               None 0.3720 23,078,351.5894
# 1  {'alpha': 17.700000000000024, 'fit_intercept':... 0.8012 23,866,764.3565
# 2           {'alpha': 101300, 'fit_intercept': True} 0.7846 23,906,217.4033
# 3  {'alpha': 0.12, 'l1_ratio': 0.009000000000000001} 0.7899 23,853,912.3908
#
#               model  time_elapsed
# 0  LinearRegression        0.0033
# 1             Ridge        1.5333
# 2             Lasso        0.0662
# 3        ElasticNet       36.7698

# %% [markdown]
# ## Partie 2 modèles non linéaires

# %% [markdown]
# ### 1 <u>Random Forest</u>

# %% [markdown]
# #### 1-1 <u>Random Forest sans ENERGYSTARScore </u>

# %%
train_x=X_train.values
test_x=X_test.values
 

'''
param_grid = {
'n_estimators':[5,20,50,100], # nombre d'arbres
'max_features':['auto', 'sqrt'], # nombre de variables tenu en compte pour la création de chaque arbre
'max_depth':np.arange(10,130,10), # nombre maximum de niveaux dans chaque arbre de décision 
'min_samples_split':[2, 6, 10], # nombre minimal d'observation avant séparation du noeud
'min_samples_leaf':[1, 3, 4], #nombre minimal d'observation pour créer une feuille
'bootstrap':[True, False] # méthode d'échantillonnage
}   
'''
 
## best params


param_grid={'bootstrap': [False],
  'max_depth': [40],
  'max_features': ['sqrt'],
  'min_samples_leaf': [1],
  'min_samples_split': [2],
  'n_estimators': [100]}

model = RandomForestRegressor(random_state=random_state)
result=utils.grid_search_cv_func(df,target_col,feature_cols,param_grid,scoring,model,test_size,random_state,cv,train_x,test_x,train_y,test_y)


df_result=df_result.append(result,ignore_index = True)
print(result)
df_result
# Out:
# {'best_params': {'bootstrap': False, 'max_depth': 40, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}, 'R2': 0.6017114334421064, 'rmse': 24633656.843490545, 'model': 'RandomForestRegressor', 'time_elapsed': 5.767202180984896}
#                                          best_params     R2            rmse  \
# 0                                               None 0.3720 23,078,351.5894
# 1  {'alpha': 17.700000000000024, 'fit_intercept':... 0.8012 23,866,764.3565
# 2           {'alpha': 101300, 'fit_intercept': True} 0.7846 23,906,217.4033
# 3  {'alpha': 0.12, 'l1_ratio': 0.009000000000000001} 0.7899 23,853,912.3908
# 4  {'bootstrap': False, 'max_depth': 40, 'max_fea... 0.6017 24,633,656.8435
#
#                    model  time_elapsed
# 0       LinearRegression        0.0033
# 1                  Ridge        1.5333
# 2                  Lasso        0.0662
# 3             ElasticNet       36.7698
# 4  RandomForestRegressor        5.7672

# %%
#df_result['best_params']
#df_result.iloc[34][['best_params']]
result
# Out:
# {'best_params': {'bootstrap': False,
#   'max_depth': 40,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 1,
#   'min_samples_split': 2,
#   'n_estimators': 100},
#  'R2': 0.6017114334421064,
#  'rmse': 24633656.843490545,
#  'model': 'RandomForestRegressor',
#  'time_elapsed': 5.767202180984896}

# %% [markdown]
#   ### 2 <u>XGBoost</u>

# %% [markdown]
# #### 2-1 <u>XGBoost sans ENERGYSTARScore </u>

# %%
 
train_x=X_train.values
test_x=X_test.values
 

'''
param_grid = {
    'learning_rate':np.arange(0.1,1,0.1),
    'n_estimators':  np.arange(50, 110, 10),  #nombre d'arbres de décision 50
              'max_depth': np.arange(20, 50, 5)} #nombre maximum de niveaux dans chaque arbre de décision 20
# define the model/ estimator
'''

param_grid={'learning_rate': [0.1], 'max_depth': [35], 'n_estimators': [50]}

model = XGBRegressor(random_state=random_state)
result=utils.grid_search_cv_func(df,target_col,feature_cols,param_grid,scoring,model,test_size,random_state,cv,train_x,test_x,train_y,test_y)


df_result=df_result.append(result,ignore_index = True)
df_result
# Out:
#                                          best_params     R2            rmse  \
# 0                                               None 0.3720 23,078,351.5894
# 1  {'alpha': 17.700000000000024, 'fit_intercept':... 0.8012 23,866,764.3565
# 2           {'alpha': 101300, 'fit_intercept': True} 0.7846 23,906,217.4033
# 3  {'alpha': 0.12, 'l1_ratio': 0.009000000000000001} 0.7899 23,853,912.3908
# 4  {'bootstrap': False, 'max_depth': 40, 'max_fea... 0.6017 24,633,656.8435
# 5  {'learning_rate': 0.1, 'max_depth': 35, 'n_est... 0.5493 24,568,397.3639
#
#                    model  time_elapsed
# 0       LinearRegression        0.0033
# 1                  Ridge        1.5333
# 2                  Lasso        0.0662
# 3             ElasticNet       36.7698
# 4  RandomForestRegressor        5.7672
# 5           XGBRegressor        6.0241

# %%
result
# Out:
# {'best_params': {'learning_rate': 0.1, 'max_depth': 35, 'n_estimators': 50},
#  'R2': 0.5492726868407286,
#  'rmse': 24568397.363933627,
#  'model': 'XGBRegressor',
#  'time_elapsed': 6.024096545006614}

# %%
from sklearn.preprocessing import StandardScaler
Labels=df_result['model'].unique().tolist()
 
 
numeric_cols=['R2','rmse','time_elapsed']
fig, ax = plt.subplots(figsize=(40,15))
data_plot=df_result.copy()
data_plot['R2']=data_plot['R2']+2000000
data_plot['rmse']=data_plot['rmse']-200000
 
utils.bar_plot(ax,data_plot[['time_elapsed','rmse','R2']], total_width=1.5, single_width=0.9)
plt.xticks(range(len(Labels)), Labels, fontsize=20, rotation=45)

ttl = plt.title("modèles de prédictions consommation énergie sans energystartscore", fontsize=26)
ttl.set_position([.5, 1.03])
plt.show()

# %%
df_result.sort_values(by='R2',ascending=False)
# Out:
#                                          best_params     R2            rmse  \
# 1  {'alpha': 17.700000000000024, 'fit_intercept':... 0.8012 23,866,764.3565
# 3  {'alpha': 0.12, 'l1_ratio': 0.009000000000000001} 0.7899 23,853,912.3908
# 2           {'alpha': 101300, 'fit_intercept': True} 0.7846 23,906,217.4033
# 4  {'bootstrap': False, 'max_depth': 40, 'max_fea... 0.6017 24,633,656.8435
# 5  {'learning_rate': 0.1, 'max_depth': 35, 'n_est... 0.5493 24,568,397.3639
# 0                                               None 0.3720 23,078,351.5894
#
#                    model  time_elapsed
# 1                  Ridge        1.5333
# 3             ElasticNet       36.7698
# 2                  Lasso        0.0662
# 4  RandomForestRegressor        5.7672
# 5           XGBRegressor        6.0241
# 0       LinearRegression        0.0033
